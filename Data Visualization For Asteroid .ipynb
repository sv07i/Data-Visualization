# %% [markdown]
# Name : Patel Yash Shaileshkumar

# %% [markdown]
# Enrollment Number : 20MSCPHY22034

# %% [markdown]
# Course : MSC PHYSICS

# %% [markdown]
# Sem : 2

# %% [markdown]
# Reference By : Shivam Kansara

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
data = pd.read_csv("impacts.csv")
data
# Out:
#                   Object Name  Period Start  Period End  Possible Impacts  \
# 0                    2006 WP1          2017        2017                 1
# 1                     2013 YB          2017        2046                23
# 2                     2008 US          2017        2062                30
# 3                  2010 VR139          2017        2076                24
# 4                  2015 ME131          2017        2096                85
# ..                        ...           ...         ...               ...
# 678                 2014 KW76          2115        2115                 1
# 679                   2012 FN          2115        2115                 1
# 680  101955 Bennu (1999 RQ36)          2175        2199                78
# 681          410777 (2009 FD)          2185        2198                 7
# 682           29075 (1950 DA)          2880        2880                 1
#
#      Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                     5.200000e-09              17.77                28.3
# 1                     7.600000e-05               8.98                31.4
# 2                     1.600000e-05              18.33                31.4
# 3                     2.000000e-07               4.99                26.7
# 4                     2.300000e-08              19.46                19.2
# ..                             ...                ...                 ...
# 678                   2.800000e-07              15.00                28.0
# 679                   2.300000e-08               3.27                29.2
# 680                   3.700000e-04               5.99                20.2
# 681                   1.600000e-03              15.87                22.1
# 682                   1.200000e-04              14.10                17.6
#
#      Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                     0.007                     -8.31                  -8.31
# 1                     0.002                     -6.60                  -6.96
# 2                     0.002                     -6.48                  -6.87
# 3                     0.016                     -6.83                  -6.95
# 4                     0.497                     -3.85                  -4.30
# ..                      ...                       ...                    ...
# 678                   0.008                     -8.22                  -8.22
# 679                   0.005                    -10.18                 -10.20
# 680                   0.490                     -1.71                  -2.32
# 681                   0.160                     -1.78                  -1.83
# 682                   1.300                     -1.42                  -1.42
#
#     Maximum Torino Scale
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 678                    0
# 679                    0
# 680                  (*)
# 681                  (*)
# 682                  (*)
#
# [683 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Object Name                    683 non-null    object
#  1   Period Start                   683 non-null    int64
#  2   Period End                     683 non-null    int64
#  3   Possible Impacts               683 non-null    int64
#  4   Cumulative Impact Probability  683 non-null    float64
#  5   Asteroid Velocity              683 non-null    float64
#  6   Asteroid Magnitude             683 non-null    float64
#  7   Asteroid Diameter (km)         683 non-null    float64
#  8   Cumulative Palermo Scale       683 non-null    float64
#  9   Maximum Palermo Scale          683 non-null    float64
#  10  Maximum Torino Scale           683 non-null    object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 58.8+ KB

# %%
data.describe()
# Out:
#        Period Start   Period End  Possible Impacts  \
# count    683.000000   683.000000        683.000000
# mean    2062.573939  2099.680820         43.348463
# std       43.501694    37.594698        113.773280
# min     2017.000000  2017.000000          1.000000
# 25%     2034.000000  2090.000000          2.000000
# 50%     2061.000000  2109.000000          6.000000
# 75%     2085.000000  2114.000000         29.000000
# max     2880.000000  2880.000000       1144.000000
#
#        Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# count                   6.830000e+02         683.000000          683.000000
# mean                    1.539476e-04          11.462577           26.158272
# std                     2.519607e-03           6.067772            2.388296
# min                     1.100000e-10           0.340000           15.600000
# 25%                     1.100000e-07           7.240000           25.000000
# 50%                     1.700000e-06          10.500000           26.400000
# 75%                     1.550000e-05          14.810000           27.800000
# max                     6.500000e-02          39.470000           31.600000
#
#        Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale
# count              683.000000                683.000000             683.000000
# mean                 0.049378                 -6.511552              -6.804012
# std                  0.156403                  1.509189               1.476135
# min                  0.002000                -10.980000             -11.000000
# 25%                  0.010000                 -7.490000              -7.790000
# 50%                  0.017000                 -6.460000              -6.790000
# 75%                  0.033000                 -5.490000              -5.865000
# max                  2.579000                 -1.420000              -1.420000

# %%
data.head()
# Out:
#   Object Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# 1                   0.002                     -6.60                  -6.96
# 2                   0.002                     -6.48                  -6.87
# 3                   0.016                     -6.83                  -6.95
# 4                   0.497                     -3.85                  -4.30
#
#   Maximum Torino Scale
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
data['.s'].sort_values(ascending=False).head().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
data["Asteroid Diameter (km)"].value_counts().head().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Asteroid Diameter (km)'>

# %%
data['Asteroid Velocity'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Asteroid Magnitude'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[["Object Name" ,"Period Start", "Period End"]]
# Out:
#                   Object Name  Period Start  Period End
# 0                    2006 WP1          2017        2017
# 1                     2013 YB          2017        2046
# 2                     2008 US          2017        2062
# 3                  2010 VR139          2017        2076
# 4                  2015 ME131          2017        2096
# ..                        ...           ...         ...
# 678                 2014 KW76          2115        2115
# 679                   2012 FN          2115        2115
# 680  101955 Bennu (1999 RQ36)          2175        2199
# 681          410777 (2009 FD)          2185        2198
# 682           29075 (1950 DA)          2880        2880
#
# [683 rows x 3 columns]

# %%
data.iloc[0]
# Out:
# Object Name                      2006 WP1
# Period Start                         2017
# Period End                           2017
# Possible Impacts                        1
# Cumulative Impact Probability     5.2e-09
# Asteroid Velocity                   17.77
# Asteroid Magnitude                   28.3
# Asteroid Diameter (km)              0.007
# Cumulative Palermo Scale            -8.31
# Maximum Palermo Scale               -8.31
# Maximum Torino Scale                    0
# Name: 0, dtype: object

# %%
data.iloc[:,[0,1,2]]
# Out:
#                   Object Name  Period Start  Period End
# 0                    2006 WP1          2017        2017
# 1                     2013 YB          2017        2046
# 2                     2008 US          2017        2062
# 3                  2010 VR139          2017        2076
# 4                  2015 ME131          2017        2096
# ..                        ...           ...         ...
# 678                 2014 KW76          2115        2115
# 679                   2012 FN          2115        2115
# 680  101955 Bennu (1999 RQ36)          2175        2199
# 681          410777 (2009 FD)          2185        2198
# 682           29075 (1950 DA)          2880        2880
#
# [683 rows x 3 columns]

# %%
runs=data.groupby("Object Name")

# %%
v1= runs["Possible Impacts"].sum().sort_values(ascending=False).head().plot(kind="pie")
v1
# Out:
# <AxesSubplot:ylabel='Possible Impacts'>

# %%
runs["Possible Impacts"].sum().sort_values(ascending=False).shape
# Out:
# (683,)

# %%
vk = data.groupby("Object Name")
v2 = vk["Asteroid Velocity"].sum().sort_values(ascending=False).head().plot(kind="pie")
v2
# Out:
# <AxesSubplot:ylabel='Asteroid Velocity'>

# %%
vk = data.groupby("Object Name")
v2 = vk["Asteroid Magnitude"].sum().sort_values(ascending=False).head().plot(kind="pie")
v2
# Out:
# <AxesSubplot:ylabel='Asteroid Magnitude'>

# %%
sns.displot(data["Possible Impacts"])
plt.show()

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x = data["Asteroid Velocity"]
y = data["Asteroid Magnitude"]
sns.regplot(x,y)
# Out:
# C:\Users\Hp-World\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Asteroid Velocity', ylabel='Asteroid Magnitude'>
